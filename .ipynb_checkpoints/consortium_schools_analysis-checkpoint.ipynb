# %% [markdown]
# # New York City 2021 Graduation Rate Analysis
# __(Phase 1)__
# ***
# <pre>
# Name: Tenicka Norwood
# Program: self paced
# Scheduled Project Review time: 11/1/2022
# Instructor name: Joe Comeaux:
# Blog post Url:
# </pre>

# %% [markdown]
# ![International_RE_school_bus_NYC.jpg](attachment:International_RE_school_bus_NYC.jpg)
# (Source:Wikimedia Commons [https://commons.wikimedia.org/)]

# %% [markdown]
# # Overview
# ***
#
# As an educator, I am often digging deeper into data to share insights with teams both within schools and across the school district. My journey with data was rekindled in 2019 when I entered a leadership training program in my district, During the Summer months, I found myself in an awkward position, several of the data visualization tools that I leaned heavily into for my role were offline. I found myself with what my husband would call a sarcastic amount of spreadsheets that no one but myself and my immediate supervisor would touch.
#
# To paraphrase the greates woman I have ever known, my grammy Eloriosa Carey, Ooh wee, I was stuck in San Andros with no canoe. If I couldnt get my team to touch the data, how in the world would they do
# deep dives around improving student outcomes.  Luckily, my husband is in the field of analytics albeit in a completely different space and he recommended building a dashboard that mimicked the visualizations that I could no longer access.

# %% [markdown]
# The tools I used were:
# * Microsoft Excel
# * <code>VLOOKUP()</code>
# * pivot tables
# * conditional formatting

# %% [markdown]
# # Data
# ***
# My data was an externally provided set of csv files each with __17000 rows__ of data across __45 columns__ that included the following features:
# * StudentID &harr; int
# * CreditStatus &harr; string
# * CreditsEarned &harr; float
# * TermID &harr; int
# * SubjectArea &harr; string
# * CourseCode &harr; string

# %% [markdown]
# At the time, I just wanted to provide my team with accurate and informative visualizations. So, I just followed where the data and my limited skills took me: *__pivot tables__
#
# ![pivot_table_fields.png](attachment:pivot_table_fields.png)

# %% [markdown]
# I must have put in around a week using every tool in my toolbox:
#
# * StackOverflow Excel with VBA
# * edX
# * Youtube tutorials
# * EdPuzzle
# * My cohort husband Tommy
# * Microsoft Word with mail merge wizard
# I used Vlookup() to isolate features from my spreadsheets.
#
# For example I looked up a students' Cohort by  using the following code:
# <code> =VLOOKUP('Pivot Credits Accumulated'!$B$3,'general student data'!C:V,12,FALSE) </code>
#
# First I used an IF() statement <code>=IF(AND(X41<65, X41>0), "Not Yet", "No Score")</code> to generate an exam Score of:
#
# * Passing
# * No Score
# * Not Yet
#
# Then I used conditional formatting to fill a cell with:
# * light blue if a student completed a subject specific graduation exam
# * red if they had not passed a subject specific graduation exam

# %% [markdown]
# This is what I ended up with two responsive visualizations for academic advisors:
# * The first allows users search for their advisee's by student id and generate a visual that gave them instant feedback on a students' credit accumulation without killing a forest worth of trees to print permanent records, group them then disperse them.
# * The second generates a snapshot of graduation level exams for each student.
#
# I pair both visuals to the same pivot table so only one input needed to be entered per student.

# %% [markdown]
# ![pivot_table_to_visualization-4.png](attachment:pivot_table_to_visualization-4.png)

# %% [markdown]
# ![exam_visualization.png](attachment:exam_visualization.png)

# %% [markdown]
# # Lessons Learned
# * You can use <code> =Now() </code> to add dates to a cell in my ever changing set of visualizations.
# * You can use lookup tables to link to a primary key the way I did when Access was the way I interacted with databases.
# * Pivot tables can be used to create responsive visualizations

# %% [markdown]
# You know that feeling where you feel invincible, sort of like you could throw anvils across a room or complete a P90X video without crying? Well multiply that by 10 and you will have an inkling of how on top of the world I was feeling. I kept going until I realized that generating visuals that mimic existing tools was not quite what I wanted to do. Sure I had a back up plan in case the system went down at a crucial time again, but I wanted to learn more.
#
# One of the members of my extended network recommended the Flatiron school and after completing a few practice lessons and 5 zoom meetings later, I completed my application for the Flex Data Science program and am excited as I continue to learn new concepts.

# %% [markdown]
# # Digging into Data after Joining Flatiron
# ***
#
# Now before I start exploring data, I look at:
# * How clean is it?
# * How was it collected?
# * What license is it available under?
#
# I have learned that importing libraries and visualization packages allows me to be more effective in crafting insights, because my code can access other tools, projects become both more manageable and more impactful.
#
# My favorite libraries and visualization packages so far include:
# * <code> sqlite3 </code>: a library that allows accessing and manipulating databases
# * <code> pandas </code>: a data analysis and manipulation library that allows flexible reshaping of dataframes
# * <code> seaborn </code>: a data visualization library based on matplot lib

# %% [markdown]
# Right now, I am looking at data from:
#
# * [The New York State Education Department](https://data.nysed.gov/)
#
# * [NYC Open Data](https://data.cityofnewyork.us/Education/2005-2015-Graduation-Outcomes/qk7d-gecv)
#
# So I will import a set of libraries to explore this data:

# %%
# Import libraries and visualization packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# Allow plots to display and be stored inline within a notebook
# %matplotlib inline

# Set display option to readable format
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
# Read in the data
# Read Data from Box office Mojo
class_2021_NYC_graduation_data = pd.read_csv('class_of_2021_NYC_graduation_data.csv')
beacon_hs = pd.read_csv('2021_Beacon_HS_graduation_data.csv')
eastside = pd.read_csv('2021_Eastside_Community_graduation_data.csv')
essex = pd.read_csv('2021_Essex_Street_Academy_graduation_data.csv')
overall_nyc = pd.read_csv('nysed_csv.csv')

# %%
"""
This function plots a histogram given
a DataFrame, column name, title, xlabel and ylabel. 

The plot is customized to include a vertical line 
that represents the mean value of the 
"""
def plot_hist(df,column, title, xlabel, ylabel):
    # Initialize data
    data = df[column]
    mean = data.mean()
    # Set plot parameters
    fig, ax = plt.subplots(figsize = (12,8))
    # Plot histogram
    ax.hist(data, color = 'aquamarine', bins = "auto")
    # Plot vertical Line
    ax.axvline(mean, color = "black", linestyle = "dotted",label= "mean")
    #Customize title and axes labels
    ax.set_xlabel(xlabel);
    ax.set_ylabel(ylabel)
    ax.set_title(title);
    ax.legend();

# %%
"""
This function plots a barplot given
a DataFrame, column name, title, xlabel and ylabel. 

The plot is customized to include a vertical line 
that represents the mean value of the column displayed

-
Input:

df : Pandas dataframe
column_1 : column of interest in dataframe
column_2 : column of interest in dataframe

xlabel : Name of the independent variable
ylabel : Name of the dependent variable
"""
def plot_bar(df, column_1, column_2,xlabel, ylabel):
    # Initialize data
    x_values = df[column_1]
    y_values = df[column_2]
    
    # Set plot parameters
    plt.figure(figsize = (14,10))
    
    fig, ax = plt.subplots
    clrs = ['grey' if (x != max(values)) else 'blue' for x in values]
    # Plot histogram
    ax = sns.barplot(x = values, y = labels, palette = clrs)
    # Plot vertical Line
#    ax.axvline(mean, color = "black", linestyle = "dotted",label= "mean")
    #Customize title and axes labels
    ax.set_xlabel(xlabel);
    ax.set_ylabel(ylabel)
    ax.set_title(title);
    ax.legend();

# %%
def summarize_dataframe(df):
    '''
    Summarizes each column in a Pandas dataframe, where each row of the 
    summary output is a column of the input dataframe, df
    Will show the datatype of data in the column, the number of missing values
    in that column, and the number of unique values in the column
    -
    Input:
    df : Pandas dataframe
    -
    Output:
    summary : Pandas dataframe, now showing column details
    '''
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index'] # name of each variable 
    summary = summary[['Name','dtypes']] # data type of each variable
    summary['Missing'] = df.isnull().sum().values # number of missing values  
    summary['Uniques'] = df.nunique().values # number of unique values
    return summary

# %%
summarize_dataframe(class_2021_NYC_graduation_data)
# Out:
#                                     Name   dtypes  Missing  Uniques
# 0                               Category   object        0       31
# 1                            Cohort Year    int64        0        1
# 2                                 Cohort   object        0        1
# 3                         # Total Cohort    int64        0       30
# 4                                # Grads    int64        0       30
# 5                                % Grads  float64        0       27
# 6                        # Total Regents    int64        0       30
# 7              % Total Regents of Cohort  float64        0       29
# 8               % Total Regents of Grads  float64        0       16
# 9                     # Advanced Regents    int64        0       30
# 10          % Advanced Regents of Cohort  float64        0       30
# 11           % Advanced Regents of Grads  float64        0       29
# 12            # Regents without Advanced    int64        0       30
# 13  % Regents without Advanced of Cohort  float64        0       30
# 14   % Regents without Advanced of Grads  float64        0       30
# 15                               # Local    int64        0       29
# 16                     % Local of Cohort  float64        0       17
# 17                      % Local of Grads  float64        0       16
# 18                      # Still Enrolled    int64        0       30
# 19                      % Still Enrolled  float64        0       27
# 20                             # Dropout    int64        0       30
# 21                             % Dropout  float64        0       26
# 22                  # SACC (IEP Diploma)    int64        0       24
# 23        % SACC (IEP Diploma) of Cohort  float64        0       11
# 24                          # TASC (GED)    int64        0       29
# 25                % TASC (GED) of Cohort  float64        0       18

# %%
class_2021_NYC_graduation_data.head(20)
# Out:
#                   Category  Cohort Year       Cohort  # Total Cohort  # Grads  \
# 0             All Students         2016  4 year June           74523    57322
# 1                      ELL         2016  4 year June            7430     3155
# 2               Former ELL         2016  4 year June            5118     4656
# 3                  Not ELL         2016  4 year June           61975    49511
# 4                  Not SWD         2016  4 year June           59930    49928
# 5                      SWD         2016  4 year June           14593     7394
# 6                    Asian         2016  4 year June           12939    11363
# 7                    Black         2016  4 year June           19256    14202
# 8                 Hispanic         2016  4 year June           29512    21275
# 9             Multi-Racial         2016  4 year June            1068      853
# 10         Native American         2016  4 year June             698      506
# 11                   White         2016  4 year June           11050     9123
# 12                  Female         2016  4 year June           36299    30049
# 13                    Male         2016  4 year June           38224    27273
# 14            Female Asian         2016  4 year June            6162     5695
# 15            Female Black         2016  4 year June            9521     7689
# 16         Female Hispanic         2016  4 year June           14458    11331
# 17     Female Multi-Racial         2016  4 year June             544      445
# 18  Female Native American         2016  4 year June             310      243
# 19            Female White         2016  4 year June            5304     4646
#
#     % Grads  # Total Regents  % Total Regents of Cohort  \
# 0     76.90            56403                      75.70
# 1     42.50             2997                      40.30
# 2     91.00             4583                      89.50
# 3     79.90            48823                      78.80
# 4     83.30            49733                      83.00
# 5     50.70             6670                      45.70
# 6     87.80            11306                      87.40
# 7     73.80            13867                      72.00
# 8     72.10            20842                      70.60
# 9     79.90              844                      79.00
# 10    72.50              502                      71.90
# 11    82.60             9042                      81.80
# 12    82.80            29628                      81.60
# 13    71.40            26775                      70.00
# 14    92.40             5670                      92.00
# 15    80.80             7538                      79.20
# 16    78.40            11132                      77.00
# 17    81.80              441                      81.10
# 18    78.40              240                      77.40
# 19    87.60             4607                      86.90
#
#     % Total Regents of Grads  # Advanced Regents  ...  % Local of Cohort  \
# 0                      98.40               22563  ...               1.20
# 1                      95.00                 208  ...               2.10
# 2                      98.40                1303  ...               1.40
# 3                      98.60               21052  ...               1.10
# 4                      99.60               21795  ...               0.30
# 5                      90.20                 768  ...               5.00
# 6                      99.50                7605  ...               0.40
# 7                      97.60                3052  ...               1.70
# 8                      98.00                6386  ...               1.50
# 9                      98.90                 415  ...               0.80
# 10                     99.20                 193  ...               0.60
# 11                     99.10                4912  ...               0.70
# 12                     98.60               12662  ...               1.20
# 13                     98.20                9901  ...               1.30
# 14                     99.60                4024  ...               0.40
# 15                     98.00                1925  ...               1.60
# 16                     98.20                3718  ...               1.40
# 17                     99.10                 230  ...               0.70
# 18                     98.80                  96  ...               1.00
# 19                     99.20                2669  ...               0.70
#
#     % Local of Grads  # Still Enrolled  % Still Enrolled  # Dropout  \
# 0               1.60             11695             15.70       4368
# 1               5.00              2305             31.00       1704
# 2               1.60               385              7.50         57
# 3               1.40              9005             14.50       2607
# 4               0.40              6261             10.40       3124
# 5               9.80              5434             37.20       1244
# 6               0.50              1007              7.80        458
# 7               2.40              3555             18.50       1128
# 8               2.00              5356             18.10       2355
# 9               1.10               195             18.30         18
# 10              0.80               106             15.20         73
# 11              0.90              1476             13.40        336
# 12              1.40              4299             11.80       1506
# 13              1.80              7396             19.30       2862
# 14              0.40               324              5.30        115
# 15              2.00              1254             13.20        433
# 16              1.80              2074             14.30        831
# 17              0.90                90             16.50          7
# 18              1.20                41             13.20         20
# 19              0.80               516              9.70        100
#
#     % Dropout  # SACC (IEP Diploma)  % SACC (IEP Diploma) of Cohort  \
# 0        5.90                   269                            0.40
# 1       22.90                    77                            1.00
# 2        1.10                     0                            0.00
# 3        4.20                   192                            0.30
# 4        5.20                     5                            0.00
# 5        8.50                   264                            1.80
# 6        3.50                    32                            0.20
# 7        5.90                    92                            0.50
# 8        8.00                    98                            0.30
# 9        1.70                     1                            0.10
# 10      10.50                     6                            0.90
# 11       3.00                    40                            0.40
# 12       4.10                    94                            0.30
# 13       7.50                   175                            0.50
# 14       1.90                     9                            0.10
# 15       4.50                    34                            0.40
# 16       5.70                    34                            0.20
# 17       1.30                     1                            0.20
# 18       6.50                     1                            0.30
# 19       1.90                    15                            0.30
#
#     # TASC (GED)  % TASC (GED) of Cohort
# 0            852                    1.10
# 1            187                    2.50
# 2             20                    0.40
# 3            645                    1.00
# 4            604                    1.00
# 5            248                    1.70
# 6             79                    0.60
# 7            273                    1.40
# 8            420                    1.40
# 9              1                    0.10
# 10             7                    1.00
# 11            72                    0.70
# 12           345                    1.00
# 13           507                    1.30
# 14            19                    0.30
# 15           110                    1.20
# 16           184                    1.30
# 17             1                    0.20
# 18             5                    1.60
# 19            26                    0.50
#
# [20 rows x 26 columns]

# %%
df = essex

# %%
plot_hist(df, "% Grads", "TEST", "xlabel", "ylabel")
# Out:
# C:\ProgramData\Anaconda3\envs\learn-env\lib\site-packages\numpy\lib\histograms.py:403: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (a >= first_edge)
# C:\ProgramData\Anaconda3\envs\learn-env\lib\site-packages\numpy\lib\histograms.py:404: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (a <= last_edge)
# C:\ProgramData\Anaconda3\envs\learn-env\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\envs\learn-env\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plot_hist(df, "% Grads", "TEST", "xlabel", "ylabel")
# Out:
# C:\ProgramData\Anaconda3\envs\learn-env\lib\site-packages\numpy\lib\histograms.py:403: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (a >= first_edge)
# C:\ProgramData\Anaconda3\envs\learn-env\lib\site-packages\numpy\lib\histograms.py:404: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (a <= last_edge)
# C:\ProgramData\Anaconda3\envs\learn-env\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\envs\learn-env\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
SWD_NYC_2021_grad_rate = class_2021_NYC_graduation_data.groupby("Category")

# %%
SWD_NYC_2021_grad_rate.head()
# Out:
#                   Category  Cohort Year       Cohort  # Total Cohort  # Grads  \
# 0             All Students         2016  4 year June           74523    57322
# 1                      ELL         2016  4 year June            7430     3155
# 2               Former ELL         2016  4 year June            5118     4656
# 3                  Not ELL         2016  4 year June           61975    49511
# 4                  Not SWD         2016  4 year June           59930    49928
# 5                      SWD         2016  4 year June           14593     7394
# 6                    Asian         2016  4 year June           12939    11363
# 7                    Black         2016  4 year June           19256    14202
# 8                 Hispanic         2016  4 year June           29512    21275
# 9             Multi-Racial         2016  4 year June            1068      853
# 10         Native American         2016  4 year June             698      506
# 11                   White         2016  4 year June           11050     9123
# 12                  Female         2016  4 year June           36299    30049
# 13                    Male         2016  4 year June           38224    27273
# 14            Female Asian         2016  4 year June            6162     5695
# 15            Female Black         2016  4 year June            9521     7689
# 16         Female Hispanic         2016  4 year June           14458    11331
# 17     Female Multi-Racial         2016  4 year June             544      445
# 18  Female Native American         2016  4 year June             310      243
# 19            Female White         2016  4 year June            5304     4646
# 20              Male Asian         2016  4 year June            6777     5668
# 21              Male Black         2016  4 year June            9735     6513
# 22           Male Hispanic         2016  4 year June           15054     9944
# 23       Male Multi-Racial         2016  4 year June             524      408
# 24    Male Native American         2016  4 year June             388      263
# 25              Male White         2016  4 year June            5746     4477
# 26             Econ Disadv         2016  4 year June           54497    41632
# 27         Not Econ Disadv         2016  4 year June           20026    15690
# 28             Current ELL         2016  4 year June            7430     3155
# 29                Ever ELL         2016  4 year June           19099    16673
# 30               Never ELL         2016  4 year June           47994    37494
#
#     % Grads  # Total Regents  % Total Regents of Cohort  \
# 0     76.90            56403                      75.70
# 1     42.50             2997                      40.30
# 2     91.00             4583                      89.50
# 3     79.90            48823                      78.80
# 4     83.30            49733                      83.00
# 5     50.70             6670                      45.70
# 6     87.80            11306                      87.40
# 7     73.80            13867                      72.00
# 8     72.10            20842                      70.60
# 9     79.90              844                      79.00
# 10    72.50              502                      71.90
# 11    82.60             9042                      81.80
# 12    82.80            29628                      81.60
# 13    71.40            26775                      70.00
# 14    92.40             5670                      92.00
# 15    80.80             7538                      79.20
# 16    78.40            11132                      77.00
# 17    81.80              441                      81.10
# 18    78.40              240                      77.40
# 19    87.60             4607                      86.90
# 20    83.60             5636                      83.20
# 21    66.90             6329                      65.00
# 22    66.10             9710                      64.50
# 23    77.90              403                      76.90
# 24    67.80              262                      67.50
# 25    77.90             4435                      77.20
# 26    76.40            40870                      75.00
# 27    78.30            15533                      77.60
# 28    42.50             2997                      40.30
# 29    87.30            16512                      86.50
# 30    78.10            36894                      76.90
#
#     % Total Regents of Grads  # Advanced Regents  ...  % Local of Cohort  \
# 0                      98.40               22563  ...               1.20
# 1                      95.00                 208  ...               2.10
# 2                      98.40                1303  ...               1.40
# 3                      98.60               21052  ...               1.10
# 4                      99.60               21795  ...               0.30
# 5                      90.20                 768  ...               5.00
# 6                      99.50                7605  ...               0.40
# 7                      97.60                3052  ...               1.70
# 8                      98.00                6386  ...               1.50
# 9                      98.90                 415  ...               0.80
# 10                     99.20                 193  ...               0.60
# 11                     99.10                4912  ...               0.70
# 12                     98.60               12662  ...               1.20
# 13                     98.20                9901  ...               1.30
# 14                     99.60                4024  ...               0.40
# 15                     98.00                1925  ...               1.60
# 16                     98.20                3718  ...               1.40
# 17                     99.10                 230  ...               0.70
# 18                     98.80                  96  ...               1.00
# 19                     99.20                2669  ...               0.70
# 20                     99.40                3581  ...               0.50
# 21                     97.20                1127  ...               1.90
# 22                     97.60                2668  ...               1.60
# 23                     98.80                 185  ...               1.00
# 24                     99.60                  97  ...               0.30
# 25                     99.10                2243  ...               0.70
# 26                     98.20               14877  ...               1.40
# 27                     99.00                7686  ...               0.80
# 28                     95.00                 208  ...               2.10
# 29                     99.00                7289  ...               0.80
# 30                     98.40               15066  ...               1.30
#
#     % Local of Grads  # Still Enrolled  % Still Enrolled  # Dropout  \
# 0               1.60             11695             15.70       4368
# 1               5.00              2305             31.00       1704
# 2               1.60               385              7.50         57
# 3               1.40              9005             14.50       2607
# 4               0.40              6261             10.40       3124
# 5               9.80              5434             37.20       1244
# 6               0.50              1007              7.80        458
# 7               2.40              3555             18.50       1128
# 8               2.00              5356             18.10       2355
# 9               1.10               195             18.30         18
# 10              0.80               106             15.20         73
# 11              0.90              1476             13.40        336
# 12              1.40              4299             11.80       1506
# 13              1.80              7396             19.30       2862
# 14              0.40               324              5.30        115
# 15              2.00              1254             13.20        433
# 16              1.80              2074             14.30        831
# 17              0.90                90             16.50          7
# 18              1.20                41             13.20         20
# 19              0.80               516              9.70        100
# 20              0.60               683             10.10        343
# 21              2.80              2301             23.60        695
# 22              2.40              3282             21.80       1524
# 23              1.20               105             20.00         11
# 24              0.40                65             16.80         53
# 25              0.90               960             16.70        236
# 26              1.80              8655             15.90       3271
# 27              1.00              3040             15.20       1097
# 28              5.00              2305             31.00       1704
# 29              1.00              1875              9.80        408
# 30              1.60              7515             15.70       2256
#
#     % Dropout  # SACC (IEP Diploma)  % SACC (IEP Diploma) of Cohort  \
# 0        5.90                   269                            0.40
# 1       22.90                    77                            1.00
# 2        1.10                     0                            0.00
# 3        4.20                   192                            0.30
# 4        5.20                     5                            0.00
# 5        8.50                   264                            1.80
# 6        3.50                    32                            0.20
# 7        5.90                    92                            0.50
# 8        8.00                    98                            0.30
# 9        1.70                     1                            0.10
# 10      10.50                     6                            0.90
# 11       3.00                    40                            0.40
# 12       4.10                    94                            0.30
# 13       7.50                   175                            0.50
# 14       1.90                     9                            0.10
# 15       4.50                    34                            0.40
# 16       5.70                    34                            0.20
# 17       1.30                     1                            0.20
# 18       6.50                     1                            0.30
# 19       1.90                    15                            0.30
# 20       5.10                    23                            0.30
# 21       7.10                    58                            0.60
# 22      10.10                    64                            0.40
# 23       2.10                     0                            0.00
# 24      13.70                     5                            1.30
# 25       4.10                    25                            0.40
# 26       6.00                   244                            0.40
# 27       5.50                    25                            0.10
# 28      22.90                    77                            1.00
# 29       2.10                    11                            0.10
# 30       4.70                   181                            0.40
#
#     # TASC (GED)  % TASC (GED) of Cohort
# 0            852                    1.10
# 1            187                    2.50
# 2             20                    0.40
# 3            645                    1.00
# 4            604                    1.00
# 5            248                    1.70
# 6             79                    0.60
# 7            273                    1.40
# 8            420                    1.40
# 9              1                    0.10
# 10             7                    1.00
# 11            72                    0.70
# 12           345                    1.00
# 13           507                    1.30
# 14            19                    0.30
# 15           110                    1.20
# 16           184                    1.30
# 17             1                    0.20
# 18             5                    1.60
# 19            26                    0.50
# 20            60                    0.90
# 21           163                    1.70
# 22           236                    1.60
# 23             0                    0.00
# 24             2                    0.50
# 25            46                    0.80
# 26           681                    1.20
# 27           171                    0.90
# 28           187                    2.50
# 29           130                    0.70
# 30           535                    1.10
#
# [31 rows x 26 columns]

# %%
summarize_dataframe(overall_nyc)
# Out:
#                                    Name   dtypes  Missing  Uniques
# 0                            Unnamed: 0  float64        1       23
# 1                              Subgroup   object        0       24
# 2                                 Total   object        0       23
# 3                             GRAD RATE   object        0       23
# 4                           GRAD RATE.1   object        0       16
# 5     REGENTS WITH ADVANCED DESIGNATION   object        0       23
# 6   REGENTS WITH ADVANCED DESIGNATION.1   object        0       20
# 7                       REGENTS DIPLOMA   object        0       23
# 8                     REGENTS DIPLOMA.1   object        0       14
# 9                         LOCAL DIPLOMA   object        0       21
# 10                      LOCAL DIPLOMA.1   object        0        6
# 11                     NON DIPLOMA CRED   object        0       21
# 12                   NON DIPLOMA CRED.1   object        0        4
# 13                       STILL ENROLLED   object        0       23
# 14                     STILL ENROLLED.1   object        0       15
# 15                         GED TRANSFER   object        0       21
# 16                       GED TRANSFER.1   object        0        5
# 17                              DROPOUT   object        0       21
# 18                            DROPOUT.1   object        0       11

# %%
overall_nyc.head()
# Out:
#    Unnamed: 0                    Subgroup  Total GRAD RATE GRAD RATE.1  \
# 0         nan                    Subgroup  Total         #           %
# 1        0.00                All Students  80294     62636         78%
# 2        1.00                      Female  38739     32341         83%
# 3        2.00                        Male  41555     30295         73%
# 4        3.00  General Education Students  62760     53154         85%
#
#   REGENTS WITH ADVANCED DESIGNATION REGENTS WITH ADVANCED DESIGNATION.1  \
# 0                                 #                                   %
# 1                             27739                                 35%
# 2                             15447                                 40%
# 3                             12292                                 30%
# 4                             26261                                 42%
#
#   REGENTS DIPLOMA REGENTS DIPLOMA.1 LOCAL DIPLOMA LOCAL DIPLOMA.1  \
# 0               #                 %             #               %
# 1           34114               42%           783              1%
# 2           16523               43%           371              1%
# 3           17591               42%           412              1%
# 4           26698               43%           195              0%
#
#   NON DIPLOMA CRED NON DIPLOMA CRED.1 STILL ENROLLED STILL ENROLLED.1  \
# 0                #                  %              #                %
# 1              235                 0%          13020              16%
# 2               91                 0%           4831              12%
# 3              144                 0%           8189              20%
# 4                4                 0%           6642              11%
#
#   GED TRANSFER GED TRANSFER.1 DROPOUT DROPOUT.1
# 0            #              %       #         %
# 1          603             1%    3751        5%
# 2          225             1%    1242        3%
# 3          378             1%    2509        6%
# 4          395             1%    2550        4%

# %%
for col in overall_nyc.columns:
    print(col)
# Out:
# Unnamed: 0
# Subgroup
# Total
# GRAD RATE
# GRAD RATE.1
# REGENTS WITH ADVANCED DESIGNATION
# REGENTS WITH ADVANCED DESIGNATION.1
# REGENTS DIPLOMA
# REGENTS DIPLOMA.1
# LOCAL DIPLOMA
# LOCAL DIPLOMA.1
# NON DIPLOMA CRED
# NON DIPLOMA CRED.1
# STILL ENROLLED
# STILL ENROLLED.1
# GED TRANSFER
# GED TRANSFER.1
# DROPOUT
# DROPOUT.1

# %%
overall_nyc.rename(columns={'Unamed': 'index', 'Subgroup': 'Subgroup', 'GRAD RATE' : 'GRAD RATE', 'GRAD RATE.1' :'GRAD PERCENTAGE',
                      'REGENTS WITH ADVANCED DESIGNATION' : 'REGENTS WITH ADVANCED DESIGNATION' 
                       ,'REGENTS WITH ADVANCED DESIGNATION.1' : 'REGENTS WITH ADVANCED DESIGNATION PERCENTAGE' ,
                       'REGENTS DIPLOMA' : 'REGENTS DIPLOMA', 'REGENTS DIPLOMA.1' : 'REGENTS DIPLOMA PERCENTAGE',
                      'LOCAL DIPLOMA' : 'LOCAL DIPLOMA', 'LOCAL DIPLOMA.1' : 'LOCAL DIPLOMA PERCENTAGE', 
                      'STILL ENROLLED' : 'STILL ENROLLED', 'STILL ENROLLED.1': 'STILL ENROLLED PERCENTAGE',
                      'GED TRANSFER': 'GED TRANSFER', 'GED TRANSFER.1' :'GED TRANSFER PERCENTAGE', 
                      'DROPOUT' :'DROPOUT', 'DROPOUT.1': 'DROPOUT PERCENTAGE'}, inplace=True)

# %%
overall_nyc.head()
# Out:
#    Unnamed: 0                    Subgroup  Total GRAD RATE GRAD PERCENTAGE  \
# 0         nan                    Subgroup  Total         #               %
# 1        0.00                All Students  80294     62636             78%
# 2        1.00                      Female  38739     32341             83%
# 3        2.00                        Male  41555     30295             73%
# 4        3.00  General Education Students  62760     53154             85%
#
#   REGENTS WITH ADVANCED DESIGNATION  \
# 0                                 #
# 1                             27739
# 2                             15447
# 3                             12292
# 4                             26261
#
#   REGENTS WITH ADVANCED DESIGNATION PERCENTAGE REGENTS DIPLOMA  \
# 0                                            %               #
# 1                                          35%           34114
# 2                                          40%           16523
# 3                                          30%           17591
# 4                                          42%           26698
#
#   REGENTS DIPLOMA PERCENTAGE LOCAL DIPLOMA LOCAL DIPLOMA PERCENTAGE  \
# 0                          %             #                        %
# 1                        42%           783                       1%
# 2                        43%           371                       1%
# 3                        42%           412                       1%
# 4                        43%           195                       0%
#
#   NON DIPLOMA CRED NON DIPLOMA CRED.1 STILL ENROLLED  \
# 0                #                  %              #
# 1              235                 0%          13020
# 2               91                 0%           4831
# 3              144                 0%           8189
# 4                4                 0%           6642
#
#   STILL ENROLLED PERCENTAGE GED TRANSFER GED TRANSFER PERCENTAGE DROPOUT  \
# 0                         %            #                       %       #
# 1                       16%          603                      1%    3751
# 2                       12%          225                      1%    1242
# 3                       20%          378                      1%    2509
# 4                       11%          395                      1%    2550
#
#   DROPOUT PERCENTAGE
# 0                  %
# 1                 5%
# 2                 3%
# 3                 6%
# 4                 4%

# %%
overall_nyc.drop(labels = "Unnamed: 0", axis = 1, inplace = True)

# %%
overall_nyc = overall_nyc.drop(0)

# %%
overall_nyc.head()
# Out:
#                      Subgroup  Total GRAD RATE GRAD PERCENTAGE  \
# 1                All Students  80294     62636             78%
# 2                      Female  38739     32341             83%
# 3                        Male  41555     30295             73%
# 4  General Education Students  62760     53154             85%
# 5  Students with Disabilities  17534      9482             54%
#
#   REGENTS WITH ADVANCED DESIGNATION  \
# 1                             27739
# 2                             15447
# 3                             12292
# 4                             26261
# 5                              1478
#
#   REGENTS WITH ADVANCED DESIGNATION PERCENTAGE REGENTS DIPLOMA  \
# 1                                          35%           34114
# 2                                          40%           16523
# 3                                          30%           17591
# 4                                          42%           26698
# 5                                           8%            7416
#
#   REGENTS DIPLOMA PERCENTAGE LOCAL DIPLOMA LOCAL DIPLOMA PERCENTAGE  \
# 1                        42%           783                       1%
# 2                        43%           371                       1%
# 3                        42%           412                       1%
# 4                        43%           195                       0%
# 5                        42%           588                       3%
#
#   NON DIPLOMA CRED NON DIPLOMA CRED.1 STILL ENROLLED  \
# 1              235                 0%          13020
# 2               91                 0%           4831
# 3              144                 0%           8189
# 4                4                 0%           6642
# 5              231                 1%           6378
#
#   STILL ENROLLED PERCENTAGE GED TRANSFER GED TRANSFER PERCENTAGE DROPOUT  \
# 1                       16%          603                      1%    3751
# 2                       12%          225                      1%    1242
# 3                       20%          378                      1%    2509
# 4                       11%          395                      1%    2550
# 5                       36%          208                      1%    1201
#
#   DROPOUT PERCENTAGE
# 1                 5%
# 2                 3%
# 3                 6%
# 4                 4%
# 5                 7%

# %%
summarize_dataframe(overall_nyc)
# Out:
#                                             Name  dtypes  Missing  Uniques
# 0                                       Subgroup  object        0       23
# 1                                          Total  object        0       22
# 2                                      GRAD RATE  object        0       22
# 3                                GRAD PERCENTAGE  object        0       15
# 4              REGENTS WITH ADVANCED DESIGNATION  object        0       22
# 5   REGENTS WITH ADVANCED DESIGNATION PERCENTAGE  object        0       19
# 6                                REGENTS DIPLOMA  object        0       22
# 7                     REGENTS DIPLOMA PERCENTAGE  object        0       13
# 8                                  LOCAL DIPLOMA  object        0       20
# 9                       LOCAL DIPLOMA PERCENTAGE  object        0        5
# 10                              NON DIPLOMA CRED  object        0       20
# 11                            NON DIPLOMA CRED.1  object        0        3
# 12                                STILL ENROLLED  object        0       22
# 13                     STILL ENROLLED PERCENTAGE  object        0       14
# 14                                  GED TRANSFER  object        0       20
# 15                       GED TRANSFER PERCENTAGE  object        0        4
# 16                                       DROPOUT  object        0       20
# 17                            DROPOUT PERCENTAGE  object        0       10

# %%
overall_nyc.head(24)
# Out:
#                                            Subgroup  Total GRAD RATE  \
# 1                                      All Students  80294     62636
# 2                                            Female  38739     32341
# 3                                              Male  41555     30295
# 4                        General Education Students  62760     53154
# 5                        Students with Disabilities  17534      9482
# 6                  American Indian or Alaska Native    913       707
# 7   Asian or Native Hawaiian/Other Pacific Islander  13154     11658
# 8                         Black or African American  20655     15556
# 9                                Hispanic or Latino  31662     23656
# 10                                            White  12486      9906
# 11                                      Multiracial   1424      1153
# 12                       Economically Disadvantaged  57636     44949
# 13                   Not Economically Disadvantaged  22658     17687
# 14                         English Language Learner   8538      4744
# 15                     Non-English Language Learner  71756     57892
# 16                                   In Foster Care    433       175
# 17                               Not in Foster Care  79861     62461
# 18                                         Homeless   5788      3858
# 19                                     Not Homeless  74506     58778
# 20                                          Migrant      0         0
# 21                                      Not Migrant  80294     62636
# 22                           Parent in Armed Forces     11         4
# 23                       Parent Not in Armed Forces  80283     62632
#
#    GRAD PERCENTAGE REGENTS WITH ADVANCED DESIGNATION  \
# 1              78%                             27739
# 2              83%                             15447
# 3              73%                             12292
# 4              85%                             26261
# 5              54%                              1478
# 6              77%                               280
# 7              89%                              8156
# 8              75%                              4389
# 9              75%                              8799
# 10             79%                              5593
# 11             81%                               522
# 12             78%                             18706
# 13             78%                              9033
# 14             56%                               819
# 15             81%                             26920
# 16             40%                                25
# 17             78%                             27714
# 18             67%                              1135
# 19             79%                             26604
# 20              0%                                 0
# 21             78%                             27739
# 22             36%                                 2
# 23             78%                             27737
#
#    REGENTS WITH ADVANCED DESIGNATION PERCENTAGE REGENTS DIPLOMA  \
# 1                                           35%           34114
# 2                                           40%           16523
# 3                                           30%           17591
# 4                                           42%           26698
# 5                                            8%            7416
# 6                                           31%             414
# 7                                           62%            3484
# 8                                           21%           10966
# 9                                           28%           14627
# 10                                          45%            4065
# 11                                          37%             558
# 12                                          32%           25978
# 13                                          40%            8136
# 14                                          10%            3901
# 15                                          38%           30213
# 16                                           6%             148
# 17                                          35%           33966
# 18                                          20%            2700
# 19                                          36%           31414
# 20                                           0%               0
# 21                                          35%           34114
# 22                                          18%               2
# 23                                          35%           34112
#
#    REGENTS DIPLOMA PERCENTAGE LOCAL DIPLOMA LOCAL DIPLOMA PERCENTAGE  \
# 1                         42%           783                       1%
# 2                         43%           371                       1%
# 3                         42%           412                       1%
# 4                         43%           195                       0%
# 5                         42%           588                       3%
# 6                         45%            13                       1%
# 7                         26%            18                       0%
# 8                         53%           201                       1%
# 9                         46%           230                       1%
# 10                        33%           248                       2%
# 11                        39%            73                       5%
# 12                        45%           265                       0%
# 13                        36%           518                       2%
# 14                        46%            24                       0%
# 15                        42%           759                       1%
# 16                        34%             2                       0%
# 17                        43%           781                       1%
# 18                        47%            23                       0%
# 19                        42%           760                       1%
# 20                         0%             0                       0%
# 21                        42%           783                       1%
# 22                        18%             0                       0%
# 23                        42%           783                       1%
#
#    NON DIPLOMA CRED NON DIPLOMA CRED.1 STILL ENROLLED  \
# 1               235                 0%          13020
# 2                91                 0%           4831
# 3               144                 0%           8189
# 4                 4                 0%           6642
# 5               231                 1%           6378
# 6                 0                 0%            150
# 7                14                 0%           1074
# 8                75                 0%           3786
# 9               115                 0%           5549
# 10               28                 0%           2218
# 11                3                 0%            243
# 12              201                 0%           9165
# 13               34                 0%           3855
# 14               76                 1%           2273
# 15              159                 0%          10747
# 16                3                 1%            149
# 17              232                 0%          12871
# 18               17                 0%           1121
# 19              218                 0%          11899
# 20                0                 0%              0
# 21              235                 0%          13020
# 22                2                18%              5
# 23              233                 0%          13015
#
#    STILL ENROLLED PERCENTAGE GED TRANSFER GED TRANSFER PERCENTAGE DROPOUT  \
# 1                        16%          603                      1%    3751
# 2                        12%          225                      1%    1242
# 3                        20%          378                      1%    2509
# 4                        11%          395                      1%    2550
# 5                        36%          208                      1%    1201
# 6                        16%           14                      2%      42
# 7                         8%           54                      0%     352
# 8                        18%          195                      1%    1017
# 9                        18%          294                      1%    2029
# 10                       18%           44                      0%     288
# 11                       17%            2                      0%      23
# 12                       16%          475                      1%    2803
# 13                       17%          128                      1%     948
# 14                       27%          106                      1%    1337
# 15                       15%          497                      1%    2414
# 16                       34%           27                      6%      74
# 17                       16%          576                      1%    3677
# 18                       19%           76                      1%     710
# 19                       16%          527                      1%    3041
# 20                        0%            0                      0%       0
# 21                       16%          603                      1%    3751
# 22                       45%            0                      0%       0
# 23                       16%          603                      1%    3751
#
#    DROPOUT PERCENTAGE
# 1                  5%
# 2                  3%
# 3                  6%
# 4                  4%
# 5                  7%
# 6                  5%
# 7                  3%
# 8                  5%
# 9                  6%
# 10                 2%
# 11                 2%
# 12                 5%
# 13                 4%
# 14                16%
# 15                 3%
# 16                17%
# 17                 5%
# 18                12%
# 19                 4%
# 20                 0%
# 21                 5%
# 22                 0%
# 23                 5%

# %%
overall_nyc = overall_nyc.replace({"\%":""}, regex = True)
overall_nyc.head(24)
# Out:
#                                            Subgroup  Total GRAD RATE  \
# 1                                      All Students  80294     62636
# 2                                            Female  38739     32341
# 3                                              Male  41555     30295
# 4                        General Education Students  62760     53154
# 5                        Students with Disabilities  17534      9482
# 6                  American Indian or Alaska Native    913       707
# 7   Asian or Native Hawaiian/Other Pacific Islander  13154     11658
# 8                         Black or African American  20655     15556
# 9                                Hispanic or Latino  31662     23656
# 10                                            White  12486      9906
# 11                                      Multiracial   1424      1153
# 12                       Economically Disadvantaged  57636     44949
# 13                   Not Economically Disadvantaged  22658     17687
# 14                         English Language Learner   8538      4744
# 15                     Non-English Language Learner  71756     57892
# 16                                   In Foster Care    433       175
# 17                               Not in Foster Care  79861     62461
# 18                                         Homeless   5788      3858
# 19                                     Not Homeless  74506     58778
# 20                                          Migrant      0         0
# 21                                      Not Migrant  80294     62636
# 22                           Parent in Armed Forces     11         4
# 23                       Parent Not in Armed Forces  80283     62632
#
#    GRAD PERCENTAGE REGENTS WITH ADVANCED DESIGNATION  \
# 1               78                             27739
# 2               83                             15447
# 3               73                             12292
# 4               85                             26261
# 5               54                              1478
# 6               77                               280
# 7               89                              8156
# 8               75                              4389
# 9               75                              8799
# 10              79                              5593
# 11              81                               522
# 12              78                             18706
# 13              78                              9033
# 14              56                               819
# 15              81                             26920
# 16              40                                25
# 17              78                             27714
# 18              67                              1135
# 19              79                             26604
# 20               0                                 0
# 21              78                             27739
# 22              36                                 2
# 23              78                             27737
#
#    REGENTS WITH ADVANCED DESIGNATION PERCENTAGE REGENTS DIPLOMA  \
# 1                                            35           34114
# 2                                            40           16523
# 3                                            30           17591
# 4                                            42           26698
# 5                                             8            7416
# 6                                            31             414
# 7                                            62            3484
# 8                                            21           10966
# 9                                            28           14627
# 10                                           45            4065
# 11                                           37             558
# 12                                           32           25978
# 13                                           40            8136
# 14                                           10            3901
# 15                                           38           30213
# 16                                            6             148
# 17                                           35           33966
# 18                                           20            2700
# 19                                           36           31414
# 20                                            0               0
# 21                                           35           34114
# 22                                           18               2
# 23                                           35           34112
#
#    REGENTS DIPLOMA PERCENTAGE LOCAL DIPLOMA LOCAL DIPLOMA PERCENTAGE  \
# 1                          42           783                        1
# 2                          43           371                        1
# 3                          42           412                        1
# 4                          43           195                        0
# 5                          42           588                        3
# 6                          45            13                        1
# 7                          26            18                        0
# 8                          53           201                        1
# 9                          46           230                        1
# 10                         33           248                        2
# 11                         39            73                        5
# 12                         45           265                        0
# 13                         36           518                        2
# 14                         46            24                        0
# 15                         42           759                        1
# 16                         34             2                        0
# 17                         43           781                        1
# 18                         47            23                        0
# 19                         42           760                        1
# 20                          0             0                        0
# 21                         42           783                        1
# 22                         18             0                        0
# 23                         42           783                        1
#
#    NON DIPLOMA CRED NON DIPLOMA CRED.1 STILL ENROLLED  \
# 1               235                  0          13020
# 2                91                  0           4831
# 3               144                  0           8189
# 4                 4                  0           6642
# 5               231                  1           6378
# 6                 0                  0            150
# 7                14                  0           1074
# 8                75                  0           3786
# 9               115                  0           5549
# 10               28                  0           2218
# 11                3                  0            243
# 12              201                  0           9165
# 13               34                  0           3855
# 14               76                  1           2273
# 15              159                  0          10747
# 16                3                  1            149
# 17              232                  0          12871
# 18               17                  0           1121
# 19              218                  0          11899
# 20                0                  0              0
# 21              235                  0          13020
# 22                2                 18              5
# 23              233                  0          13015
#
#    STILL ENROLLED PERCENTAGE GED TRANSFER GED TRANSFER PERCENTAGE DROPOUT  \
# 1                         16          603                       1    3751
# 2                         12          225                       1    1242
# 3                         20          378                       1    2509
# 4                         11          395                       1    2550
# 5                         36          208                       1    1201
# 6                         16           14                       2      42
# 7                          8           54                       0     352
# 8                         18          195                       1    1017
# 9                         18          294                       1    2029
# 10                        18           44                       0     288
# 11                        17            2                       0      23
# 12                        16          475                       1    2803
# 13                        17          128                       1     948
# 14                        27          106                       1    1337
# 15                        15          497                       1    2414
# 16                        34           27                       6      74
# 17                        16          576                       1    3677
# 18                        19           76                       1     710
# 19                        16          527                       1    3041
# 20                         0            0                       0       0
# 21                        16          603                       1    3751
# 22                        45            0                       0       0
# 23                        16          603                       1    3751
#
#    DROPOUT PERCENTAGE
# 1                   5
# 2                   3
# 3                   6
# 4                   4
# 5                   7
# 6                   5
# 7                   3
# 8                   5
# 9                   6
# 10                  2
# 11                  2
# 12                  5
# 13                  4
# 14                 16
# 15                  3
# 16                 17
# 17                  5
# 18                 12
# 19                  4
# 20                  0
# 21                  5
# 22                  0
# 23                  5

# %%
overall_nyc.head(24)
# Out:
#                                            Subgroup  Total GRAD RATE  \
# 1                                      All Students  80294     62636
# 2                                            Female  38739     32341
# 3                                              Male  41555     30295
# 4                        General Education Students  62760     53154
# 5                        Students with Disabilities  17534      9482
# 6                  American Indian or Alaska Native    913       707
# 7   Asian or Native Hawaiian/Other Pacific Islander  13154     11658
# 8                         Black or African American  20655     15556
# 9                                Hispanic or Latino  31662     23656
# 10                                            White  12486      9906
# 11                                      Multiracial   1424      1153
# 12                       Economically Disadvantaged  57636     44949
# 13                   Not Economically Disadvantaged  22658     17687
# 14                         English Language Learner   8538      4744
# 15                     Non-English Language Learner  71756     57892
# 16                                   In Foster Care    433       175
# 17                               Not in Foster Care  79861     62461
# 18                                         Homeless   5788      3858
# 19                                     Not Homeless  74506     58778
# 20                                          Migrant      0         0
# 21                                      Not Migrant  80294     62636
# 22                           Parent in Armed Forces     11         4
# 23                       Parent Not in Armed Forces  80283     62632
#
#    GRAD PERCENTAGE REGENTS WITH ADVANCED DESIGNATION  \
# 1               78                             27739
# 2               83                             15447
# 3               73                             12292
# 4               85                             26261
# 5               54                              1478
# 6               77                               280
# 7               89                              8156
# 8               75                              4389
# 9               75                              8799
# 10              79                              5593
# 11              81                               522
# 12              78                             18706
# 13              78                              9033
# 14              56                               819
# 15              81                             26920
# 16              40                                25
# 17              78                             27714
# 18              67                              1135
# 19              79                             26604
# 20               0                                 0
# 21              78                             27739
# 22              36                                 2
# 23              78                             27737
#
#    REGENTS WITH ADVANCED DESIGNATION PERCENTAGE REGENTS DIPLOMA  \
# 1                                            35           34114
# 2                                            40           16523
# 3                                            30           17591
# 4                                            42           26698
# 5                                             8            7416
# 6                                            31             414
# 7                                            62            3484
# 8                                            21           10966
# 9                                            28           14627
# 10                                           45            4065
# 11                                           37             558
# 12                                           32           25978
# 13                                           40            8136
# 14                                           10            3901
# 15                                           38           30213
# 16                                            6             148
# 17                                           35           33966
# 18                                           20            2700
# 19                                           36           31414
# 20                                            0               0
# 21                                           35           34114
# 22                                           18               2
# 23                                           35           34112
#
#    REGENTS DIPLOMA PERCENTAGE LOCAL DIPLOMA LOCAL DIPLOMA PERCENTAGE  \
# 1                          42           783                        1
# 2                          43           371                        1
# 3                          42           412                        1
# 4                          43           195                        0
# 5                          42           588                        3
# 6                          45            13                        1
# 7                          26            18                        0
# 8                          53           201                        1
# 9                          46           230                        1
# 10                         33           248                        2
# 11                         39            73                        5
# 12                         45           265                        0
# 13                         36           518                        2
# 14                         46            24                        0
# 15                         42           759                        1
# 16                         34             2                        0
# 17                         43           781                        1
# 18                         47            23                        0
# 19                         42           760                        1
# 20                          0             0                        0
# 21                         42           783                        1
# 22                         18             0                        0
# 23                         42           783                        1
#
#    NON DIPLOMA CRED NON DIPLOMA CRED.1 STILL ENROLLED  \
# 1               235                  0          13020
# 2                91                  0           4831
# 3               144                  0           8189
# 4                 4                  0           6642
# 5               231                  1           6378
# 6                 0                  0            150
# 7                14                  0           1074
# 8                75                  0           3786
# 9               115                  0           5549
# 10               28                  0           2218
# 11                3                  0            243
# 12              201                  0           9165
# 13               34                  0           3855
# 14               76                  1           2273
# 15              159                  0          10747
# 16                3                  1            149
# 17              232                  0          12871
# 18               17                  0           1121
# 19              218                  0          11899
# 20                0                  0              0
# 21              235                  0          13020
# 22                2                 18              5
# 23              233                  0          13015
#
#    STILL ENROLLED PERCENTAGE GED TRANSFER GED TRANSFER PERCENTAGE DROPOUT  \
# 1                         16          603                       1    3751
# 2                         12          225                       1    1242
# 3                         20          378                       1    2509
# 4                         11          395                       1    2550
# 5                         36          208                       1    1201
# 6                         16           14                       2      42
# 7                          8           54                       0     352
# 8                         18          195                       1    1017
# 9                         18          294                       1    2029
# 10                        18           44                       0     288
# 11                        17            2                       0      23
# 12                        16          475                       1    2803
# 13                        17          128                       1     948
# 14                        27          106                       1    1337
# 15                        15          497                       1    2414
# 16                        34           27                       6      74
# 17                        16          576                       1    3677
# 18                        19           76                       1     710
# 19                        16          527                       1    3041
# 20                         0            0                       0       0
# 21                        16          603                       1    3751
# 22                        45            0                       0       0
# 23                        16          603                       1    3751
#
#    DROPOUT PERCENTAGE
# 1                   5
# 2                   3
# 3                   6
# 4                   4
# 5                   7
# 6                   5
# 7                   3
# 8                   5
# 9                   6
# 10                  2
# 11                  2
# 12                  5
# 13                  4
# 14                 16
# 15                  3
# 16                 17
# 17                  5
# 18                 12
# 19                  4
# 20                  0
# 21                  5
# 22                  0
# 23                  5

# %%
overall_nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 1 to 23
# Data columns (total 18 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Subgroup                                      23 non-null     object
#  1   Total                                         23 non-null     object
#  2   GRAD RATE                                     23 non-null     object
#  3   GRAD PERCENTAGE                               23 non-null     object
#  4   REGENTS WITH ADVANCED DESIGNATION             23 non-null     object
#  5   REGENTS WITH ADVANCED DESIGNATION PERCENTAGE  23 non-null     object
#  6   REGENTS DIPLOMA                               23 non-null     object
#  7   REGENTS DIPLOMA PERCENTAGE                    23 non-null     object
#  8   LOCAL DIPLOMA                                 23 non-null     object
#  9   LOCAL DIPLOMA PERCENTAGE                      23 non-null     object
#  10  NON DIPLOMA CRED                              23 non-null     object
#  11  NON DIPLOMA CRED.1                            23 non-null     object
#  12  STILL ENROLLED                                23 non-null     object
#  13  STILL ENROLLED PERCENTAGE                     23 non-null     object
#  14  GED TRANSFER                                  23 non-null     object
#  15  GED TRANSFER PERCENTAGE                       23 non-null     object
#  16  DROPOUT                                       23 non-null     object
#  17  DROPOUT PERCENTAGE                            23 non-null     object
# dtypes: object(18)
# memory usage: 4.0+ KB

# %%
overall_nyc = overall_nyc.astype({col: int for col in overall_nyc.columns[1:]})

# %%
# Draw a nested barplot by species and sex
values = overall_nyc['Subgroup']
labels = overall_nyc['GRAD PERCENTAGE']
plt.figure(figsize =(14,10))
clrs = ['grey' if (x != max(values)) else 'blue' for x in values]
ax = sns.barplot(
        data=overall_nyc,
        x= labels, y=values,
        palette=clrs
)
ax.set_title("Graduation Rate by Subgroup for NYC PUBLIC Schools As of June 2021", weight = 'bold').set_fontsize('16')
ax.set_xlabel("Graduation Rate (%)", fontsize = '14', weight = 'bold')
ax.set_ylabel("Population", fontsize = '14', weight = 'bold');
for bar in ax.patches:
    if bar.get_width() < 79:
        bar.set_color('grey')
    else:
        bar.set_color('blue')

# %%
overall_nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 1 to 23
# Data columns (total 18 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Subgroup                                      23 non-null     object
#  1   Total                                         23 non-null     int32
#  2   GRAD RATE                                     23 non-null     int32
#  3   GRAD PERCENTAGE                               23 non-null     int32
#  4   REGENTS WITH ADVANCED DESIGNATION             23 non-null     int32
#  5   REGENTS WITH ADVANCED DESIGNATION PERCENTAGE  23 non-null     int32
#  6   REGENTS DIPLOMA                               23 non-null     int32
#  7   REGENTS DIPLOMA PERCENTAGE                    23 non-null     int32
#  8   LOCAL DIPLOMA                                 23 non-null     int32
#  9   LOCAL DIPLOMA PERCENTAGE                      23 non-null     int32
#  10  NON DIPLOMA CRED                              23 non-null     int32
#  11  NON DIPLOMA CRED.1                            23 non-null     int32
#  12  STILL ENROLLED                                23 non-null     int32
#  13  STILL ENROLLED PERCENTAGE                     23 non-null     int32
#  14  GED TRANSFER                                  23 non-null     int32
#  15  GED TRANSFER PERCENTAGE                       23 non-null     int32
#  16  DROPOUT                                       23 non-null     int32
#  17  DROPOUT PERCENTAGE                            23 non-null     int32
# dtypes: int32(17), object(1)
# memory usage: 2.5+ KB
